# %% [markdown]
# <a href="https://colab.research.google.com/github/Geethanjali295/Crop-Yield-prediction-/blob/main/Geethanjali_S_Exit_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("/content/customer_churn.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            0.0     Yes         No     1.0
# 1     5575-GNVDE    Male            0.0      No         No    34.0
# 2     3668-QPYBK    Male            0.0      No         No     2.0
# 3     7795-CFOCW    Male            0.0      No         No    45.0
# 4     9237-HQITU  Female            0.0      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7036 non-null   float64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7030 non-null   float64
#  6   PhoneService      7030 non-null   object
#  7   MultipleLines     7030 non-null   object
#  8   InternetService   7006 non-null   object
#  9   OnlineSecurity    7028 non-null   object
#  10  OnlineBackup      7028 non-null   object
#  11  DeviceProtection  7028 non-null   object
#  12  TechSupport       7028 non-null   object
#  13  StreamingTV       7021 non-null   object
#  14  StreamingMovies   7029 non-null   object
#  15  Contract          7018 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        7
# Partner              0
# Dependents           0
# tenure              13
# PhoneService        13
# MultipleLines       13
# InternetService     37
# OnlineSecurity      15
# OnlineBackup        15
# DeviceProtection    15
# TechSupport         15
# StreamingTV         22
# StreamingMovies     14
# Contract            25
# PaperlessBilling    14
# PaymentMethod        1
# MonthlyCharges      16
# TotalCharges         7
# Churn                0
# dtype: int64

# %%
# Convert 'TotalCharges' to numeric, coercing errors to NaN
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
df.dropna(inplace=True)

# %%
# Display the info to confirm data types and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6961 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        6961 non-null   object
#  1   gender            6961 non-null   object
#  2   SeniorCitizen     6961 non-null   float64
#  3   Partner           6961 non-null   object
#  4   Dependents        6961 non-null   object
#  5   tenure            6961 non-null   float64
#  6   PhoneService      6961 non-null   object
#  7   MultipleLines     6961 non-null   object
#  8   InternetService   6961 non-null   object
#  9   OnlineSecurity    6961 non-null   object
#  10  OnlineBackup      6961 non-null   object
#  11  DeviceProtection  6961 non-null   object
#  12  TechSupport       6961 non-null   object
#  13  StreamingTV       6961 non-null   object
#  14  StreamingMovies   6961 non-null   object
#  15  Contract          6961 non-null   object
# ...

# %%
numerical_cols=df.select_dtypes(include=np.number).columns
numerical_cols
for col in numerical_cols:
  sns.boxplot(df[col])
  plt.title(col)
  plt.show()

# %%
df['PaymentMethod'].unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
numeric_df = df.select_dtypes(include=np.number)
sns.heatmap(numeric_df.corr(), annot=True)
# Out:
# <Axes: >

# %%
df = df.drop(columns=['customerID'])
print("DataFrame after dropping 'customerID' column:")
display(df.head())
# Out:
# DataFrame after dropping 'customerID' column:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female            0.0     Yes         No     1.0           No
# 1    Male            0.0      No         No    34.0          Yes
# 2    Male            0.0      No         No     2.0          Yes
# 3    Male            0.0      No         No    45.0           No
# 4  Female            0.0      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder()
df=pd.get_dummies(df,columns=['gender','Partner','Dependents','PhoneService','MultipleLines','InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies','Contract','PaperlessBilling','PaymentMethod'])
df
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges Churn  \
# 0               0.0     1.0           29.85         29.85    No
# 1               0.0    34.0           56.95       1889.50    No
# 2               0.0     2.0           53.85        108.15   Yes
# 3               0.0    45.0           42.30       1840.75    No
# 4               0.0     2.0           70.70        151.65   Yes
# ...             ...     ...             ...           ...   ...
# 7038            0.0    24.0           84.80       1990.50    No
# 7039            0.0    72.0          103.20       7362.90    No
# 7040            0.0    11.0           29.60        346.45    No
# 7041            1.0     4.0           74.40        306.60   Yes
# 7042            0.0    66.0          105.65       6844.50    No
#
#       gender_Female  gender_Male  Partner_No  Partner_Yes  Dependents_No  ...  \
# 0              True        False       False         True           True  ...
# ...

# %%
bool_cols=df.select_dtypes(include='bool').columns
df[bool_cols]=df[bool_cols].astype(int)
df
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges Churn  \
# 0               0.0     1.0           29.85         29.85    No
# 1               0.0    34.0           56.95       1889.50    No
# 2               0.0     2.0           53.85        108.15   Yes
# 3               0.0    45.0           42.30       1840.75    No
# 4               0.0     2.0           70.70        151.65   Yes
# ...             ...     ...             ...           ...   ...
# 7038            0.0    24.0           84.80       1990.50    No
# 7039            0.0    72.0          103.20       7362.90    No
# 7040            0.0    11.0           29.60        346.45    No
# 7041            1.0     4.0           74.40        306.60   Yes
# 7042            0.0    66.0          105.65       6844.50    No
#
#       gender_Female  gender_Male  Partner_No  Partner_Yes  Dependents_No  ...  \
# 0                 1            0           0            1              1  ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Churn']=le.fit_transform(df['Churn'])
df['Churn']
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 6961, dtype: int64

# %%
churn_counts = df['Churn'].value_counts()
print("Churn Value Counts:")
display(churn_counts)


churn_percentages = df['Churn'].value_counts(normalize=True) * 100
print("\nChurn Percentage Distribution:")
display(churn_percentages)


plt.figure(figsize=(7, 5))
sns.barplot(x=churn_counts.index, y=churn_counts.values, palette='coolwarm')
plt.title('Distribution of Churn (0: No Churn, 1: Churn)')
plt.xlabel('Churn Status')
plt.ylabel('Number of Customers')
plt.xticks(ticks=[0, 1], labels=['No Churn', 'Churn'])
plt.show()
# Out:
# Churn Value Counts:
# Churn
# 0    5108
# 1    1853
# Name: count, dtype: int64
# Churn Percentage Distribution:
# Churn
# 0    73.380261
# 1    26.619739
# Name: proportion, dtype: float64
# /tmp/ipykernel_2435/3517975730.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=churn_counts.index, y=churn_counts.values, palette='coolwarm')

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
X = df.drop('Churn', axis=1)
y = df['Churn']

print(f"Original dataset shape: {Counter(y)}")


sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(X, y)

print(f"Resampled dataset shape: {Counter(y_res)}")
# Out:
# Original dataset shape: Counter({0: 5108, 1: 1853})
# Resampled dataset shape: Counter({0: 5108, 1: 5108})

# %%
from sklearn.model_selection import train_test_split
x=df.drop(columns=['Churn'])
y=df['Churn']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)
x_train.shape
# Out:
# (5568, 45)

# %%
x_train
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Female  \
# 1841            0.0    56.0           24.30       1261.70              1
# 64              0.0     9.0           94.40        857.25              1
# 3400            0.0    18.0           84.30       1537.90              0
# 4806            0.0    67.0           19.45       1195.95              0
# 1038            0.0    56.0           80.90       4557.50              0
# ...             ...     ...             ...           ...            ...
# 3850            0.0    51.0           83.25       4089.45              0
# 5271            0.0    13.0           66.40        831.75              0
# 5306            0.0    19.0           83.65       1465.75              0
# 5470            1.0    71.0           89.45       6435.25              1
# 933             1.0     4.0           84.60        360.10              1
#
#       gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

columns_to_scale = ['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges']
scaler.fit(x_train[columns_to_scale])

x_train_scaled = scaler.transform(x_train[columns_to_scale])
x_test_scaled = scaler.transform(x_test[columns_to_scale])

# %%
x_train_scaled_df = pd.DataFrame(x_train_scaled, columns=columns_to_scale, index=x_train.index)

# %%
x_train_scaled_df
# Out:
#       SeniorCitizen    tenure  MonthlyCharges  TotalCharges
# 1841      -0.434428  0.962056       -1.327313     -0.441859
# 64        -0.434428 -0.945292        0.991914     -0.619683
# 3400      -0.434428 -0.580056        0.657760     -0.320423
# 4806      -0.434428  1.408456       -1.487773     -0.470768
# 1038      -0.434428  0.962056        0.545273      1.007196
# ...             ...       ...             ...           ...
# 3850      -0.434428  0.759146        0.623022      0.801410
# 5271      -0.434428 -0.782965        0.065547     -0.630894
# 5306      -0.434428 -0.539474        0.636256     -0.352145
# 5470       2.301878  1.570784        0.828146      1.832781
# 933        2.301878 -1.148202        0.667686     -0.838263
#
# [5568 rows x 4 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Initialize and train the RandomForestClassifier
rf_classifier = RandomForestClassifier(random_state=42)
rf_classifier.fit(x_train_scaled, x_test_scaled)

# Make predictions on the test set
y_pred_rf = rf_classifier.predict(X_test_scaled)

# Evaluate the model
accuracy_rf = accuracy_score(x_test_scaled, y_pred_rf)
print(f"RandomForestClassifier Accuracy: {accuracy_rf:.4f}")
print("\nRandomForestClassifier Classification Report:")
print(classification_report(x_test_scaled, y_pred_rf))
# Out:
# RandomForestClassifier Accuracy: 0.8508
#
# RandomForestClassifier Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.86      1018
#            1       0.88      0.81      0.84      1026
#
#     accuracy                           0.85      2044
#    macro avg       0.85      0.85      0.85      2044
# weighted avg       0.85      0.85      0.85      2044

# %%
import xgboost as xgb

# Initialize and train the XGBClassifier
xgb_classifier = xgb.XGBClassifier(objective='binary:logistic', n_estimators=100, random_state=42)
xgb_classifier.fit(x_train_scaled, x_test_scaled)

# Make predictions on the test set
y_pred_xgb = xgb_classifier.predict(x_test_scaled)

# Evaluate the model
accuracy_xgb = accuracy_score(x_test_scaled, y_pred_xgb)
print(f"XGBClassifier Accuracy: {accuracy_xgb:.4f}")
print("\nXGBClassifier Classification Report:")
print(classification_report(x_test_scaled, y_pred_xgb))
# Out:
# XGBClassifier Accuracy: 0.8410
#
# XGBClassifier Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.85      1018
#            1       0.86      0.81      0.84      1026
#
#     accuracy                           0.84      2044
#    macro avg       0.84      0.84      0.84      2044
# weighted avg       0.84      0.84      0.84      2044

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

# Initialize and train the Decision Tree Classifier
dt_classifier = DecisionTreeClassifier(random_state=42)
dt_classifier.fit(x_train_scaled,  x_test_scaled)

# Make predictions on the test set
y_pred_dt = dt_classifier.predict( x_test_scaled)

# Evaluate the model
accuracy_dt = accuracy_score(y_test_scaled, y_pred_dt)
print(f"Decision Tree Classifier Accuracy: {accuracy_dt:.4f}")
print("\nDecision Tree Classifier Classification Report:")
print(classification_report(y_test_scaled, y_pred_dt))
# Out:
# Decision Tree Classifier Accuracy: 0.8112
#
# Decision Tree Classifier Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.81      1018
#            1       0.83      0.79      0.81      1026
#
#     accuracy                           0.81      2044
#    macro avg       0.81      0.81      0.81      2044
# weighted avg       0.81      0.81      0.81      2044

# %%
#random forest is more accurate

# %%
import pandas as pd

# Create a sample new customer data point (similar to original df structure before encoding)
# Make sure this reflects the original column names and data types
new_customer_data = pd.DataFrame({
    'gender': ['Male'],
    'SeniorCitizen': [0.0],
    'Partner': ['Yes'],
    'Dependents': ['No'],
    'tenure': [24.0],
    'PhoneService': ['Yes'],
    'MultipleLines': ['No'],
    'InternetService': ['Fiber optic'],
    'OnlineSecurity': ['No'],
    'OnlineBackup': ['Yes'],
    'DeviceProtection': ['No'],
    'TechSupport': ['No'],
    'StreamingTV': ['Yes'],
    'StreamingMovies': ['Yes'],
    'Contract': ['Month-to-month'],
    'PaperlessBilling': ['Yes'],
    'PaymentMethod': ['Electronic check'],
    'MonthlyCharges': [90.0],
    'TotalCharges': [2160.0]
})

print("Original new customer data:")
display(new_customer_data)
# Out:
# Original new customer data:
#   gender  SeniorCitizen Partner Dependents  tenure PhoneService MultipleLines  \
# 0   Male            0.0     Yes         No    24.0          Yes            No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0     Fiber optic             No          Yes               No          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0         Yes             Yes  Month-to-month              Yes
#
#       PaymentMethod  MonthlyCharges  TotalCharges
# 0  Electronic check            90.0        2160.0

# %%
# Identify categorical columns that were one-hot encoded
categorical_cols_encoded = [
    'gender','Partner','Dependents','PhoneService','MultipleLines',
    'InternetService','OnlineSecurity','OnlineBackup','DeviceProtection',
    'TechSupport','StreamingTV','StreamingMovies','Contract',
    'PaperlessBilling','PaymentMethod'
]

# One-hot encode the new customer data
# We need to ensure that all categories present in the training data are also present here,
# even if the new customer doesn't have them, to match the column structure.
# Get all columns from X_res (which is the preprocessed training data)
all_training_cols = X_res.columns.tolist()

# Perform one-hot encoding on the new customer data
new_customer_encoded = pd.get_dummies(new_customer_data, columns=categorical_cols_encoded)

# Align columns - crucial for consistent feature order
# Add missing columns with 0 and ensure order matches training data
for col in all_training_cols:
    if col not in new_customer_encoded.columns:
        new_customer_encoded[col] = 0

# Drop extra columns from new_customer_encoded if any (shouldn't happen with get_dummies, but good practice)
# This also ensures the column order matches
new_customer_processed = new_customer_encoded[all_training_cols]

# Convert boolean columns to int if any were created during get_dummies and not handled by 'all_training_cols'
# (This was done globally in xSU4OvmR1uz2)
bool_cols_new = new_customer_processed.select_dtypes(include='bool').columns
new_customer_processed[bool_cols_new] = new_customer_processed[bool_cols_new].astype(int)


# Scale numerical features using the *fitted* scaler_resampled
new_customer_scaled = new_customer_processed.copy()
new_customer_scaled[columns_to_scale] = scaler_resampled.transform(new_customer_processed[columns_to_scale])

print("Preprocessed and scaled new customer data:")
display(new_customer_scaled)
# Out:
# Preprocessed and scaled new customer data:
#    SeniorCitizen    tenure  MonthlyCharges  TotalCharges  gender_Female  \
# 0      -0.520438 -0.146869        0.772963      0.059737              0
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0            1           0            1              1               0  ...
#
#    StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# 0                    1                        1                  0
#
#    Contract_Two year  PaperlessBilling_No  PaperlessBilling_Yes  \
# 0                  0                    0                     1
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                        0
#
#    PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                      0                               1
#
#    PaymentMethod_Mailed check
# 0                           0
#
# [1 rows x 45 columns]

# %%
# Make prediction using the best-performing model (RandomForestClassifier)
prediction = rf_classifier.predict(new_customer_scaled)

# Interpret the prediction
if prediction[0] == 1:
    print("Prediction: This customer is likely to churn.")
else:
    print("Prediction: This customer is not likely to churn.")
# Out:
# Prediction: This customer is not likely to churn.

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Generate the confusion matrix for RandomForestClassifier
cm_rf = confusion_matrix(y_test_scaled, y_pred_rf)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['No Churn (Predicted)', 'Churn (Predicted)'],
            yticklabels=['No Churn (Actual)', 'Churn (Actual)'])
plt.title('Confusion Matrix for RandomForestClassifier')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
